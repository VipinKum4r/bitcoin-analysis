# %% [markdown]
# # Data preparation and cleaning
# 1. Load the file using pandas
# 2. Look at some information about the data and the columns
# 3. Fix any missing or incorrect values

# %%
import pandas as pd #imported pandas so that we can use the pandas library

# %%
df=pd.read_csv("bitcoin_data.csv") #importing the csv dataset

# %%
df #printing the first 5 and the last 5 rows of the dataset
# Out:
#           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 0        1325317920      4.39      4.39      4.39      4.39      0.455581
# 1        1325317980       NaN       NaN       NaN       NaN           NaN
# 2        1325318040       NaN       NaN       NaN       NaN           NaN
# 3        1325318100       NaN       NaN       NaN       NaN           NaN
# 4        1325318160       NaN       NaN       NaN       NaN           NaN
# ...             ...       ...       ...       ...       ...           ...
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# ...

# %%
df.columns #give names of the columns
# Out:
# Index(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)',
#        'Volume_(Currency)', 'Weighted_Price'],
#       dtype='object')

# %%
len(df.columns) #number of columns
# Out:
# 8

# %%
len(df) #number of rows
# Out:
# 4857377

# %%
df.info() #overall information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4857377 entries, 0 to 4857376
# Data columns (total 8 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Timestamp          int64
#  1   Open               float64
#  2   High               float64
#  3   Low                float64
#  4   Close              float64
#  5   Volume_(BTC)       float64
#  6   Volume_(Currency)  float64
#  7   Weighted_Price     float64
# dtypes: float64(7), int64(1)
# memory usage: 296.5 MB

# %%
df.describe() #gives mean,mode,median and other basic statistical values
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  4.857377e+06  3.613769e+06  3.613769e+06  3.613769e+06  3.613769e+06
# mean   1.471301e+09  6.009024e+03  6.013357e+03  6.004488e+03  6.009014e+03
# std    8.428019e+07  8.996247e+03  9.003521e+03  8.988778e+03  8.996360e+03
# min    1.325318e+09  3.800000e+00  3.800000e+00  1.500000e+00  1.500000e+00
# 25%    1.398179e+09  4.438600e+02  4.440000e+02  4.435200e+02  4.438600e+02
# 50%    1.471428e+09  3.596970e+03  3.598190e+03  3.595620e+03  3.597000e+03
# 75%    1.544288e+09  8.627270e+03  8.632980e+03  8.621090e+03  8.627160e+03
# max    1.617149e+09  6.176356e+04  6.178183e+04  6.167355e+04  6.178180e+04
#
#        Volume_(BTC)  Volume_(Currency)  Weighted_Price
# count  3.613769e+06       3.613769e+06    3.613769e+06
# mean   9.323249e+00       4.176284e+04    6.008935e+03
# std    3.054989e+01       1.518248e+05    8.995992e+03
# min    0.000000e+00       0.000000e+00    3.800000e+00
# ...

# %%
numerics = ['int16','int32','int64','float16','float32','float64'] #tells how many numeric columns do we have
numeric_df=df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 8

# %%
missing_percentages=df.isna().sum().sort_values(ascending=False)/len(df) #tells how many missing values do we have
missing_percentages
# Out:
# Open                 0.256025
# High                 0.256025
# Low                  0.256025
# Close                0.256025
# Volume_(BTC)         0.256025
# Volume_(Currency)    0.256025
# Weighted_Price       0.256025
# Timestamp            0.000000
# dtype: float64

# %%
missing_percentages[missing_percentages!=0].plot(kind="barh") #remove the columns with no values in missing percentages
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Exploratory  Aanalysis and Visualization

# %%
df.columns
# Out:
# Index(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume_(BTC)',
#        'Volume_(Currency)', 'Weighted_Price'],
#       dtype='object')

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
dff=df.tail()

# %%
dff
# Out:
#           Timestamp      Open      High       Low     Close  Volume_(BTC)  \
# 4857372  1617148560  58714.31  58714.31  58686.00  58686.00      1.384487
# 4857373  1617148620  58683.97  58693.43  58683.97  58685.81      7.294848
# 4857374  1617148680  58693.43  58723.84  58693.43  58723.84      1.705682
# 4857375  1617148740  58742.18  58770.38  58742.18  58760.59      0.720415
# 4857376  1617148800  58767.75  58778.18  58755.97  58778.18      2.712831
#
#          Volume_(Currency)  Weighted_Price
# 4857372       81259.372187    58692.753339
# 4857373      428158.146640    58693.226508
# 4857374      100117.070370    58696.198496
# 4857375       42332.958633    58761.866202
# 4857376      159417.751000    58764.349363

# %%
sns.barplot(x="Timestamp",y="Weighted_Price",data=dff,palette='plasma')
# Out:
# <AxesSubplot:xlabel='Timestamp', ylabel='Weighted_Price'>

# %%
sns.pairplot(dff)

# %%
sns.lineplot(x="Low",y="High",data=dff)
# Out:
# <AxesSubplot:xlabel='Low', ylabel='High'>
